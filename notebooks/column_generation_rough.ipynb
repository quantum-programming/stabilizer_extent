# %% [markdown]
# # Column Generation Rough

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from exputils.extent.cg import calculate_extent_CG
from exputils.state.random_ket import make_random_quantum_state

# %%
sns.set_theme("paper")
rc = {"mathtext.fontset": "stix"}
plt.rcParams.update(rc)


def visualize_result(n_qubit, extends, max_values):
    fig = plt.figure(figsize=(6.5, 5))
    ax1 = plt.subplot(1, 2, 1)
    ax2 = plt.subplot(1, 2, 2)
    # plot extends to ax1 with seaborn
    sns.lineplot(x=list(range(1, len(extends) + 1)), y=extends, ax=ax1, marker="o")
    ax1.set_xlabel("Iteration", fontsize=25)
    ax1.set_ylabel("Objective Value", fontsize=25)
    ax1.set_xticks(list(range(1, len(extends) + 1)))
    sns.lineplot(
        x=list(range(1, len(max_values) + 1)), y=max_values, ax=ax2, marker="o"
    )
    ax2.set_xlabel("Iteration", fontsize=25)
    ax2.set_ylabel("Max Violation", fontsize=25)
    ax2.set_xticks(list(range(1, len(max_values) + 1)))
    # fig.suptitle("(a)" if n_qubit == 7 else "(b)", fontsize=25, y=0.85, x=0.05)
    plt.tight_layout()
    plt.savefig(f"../image/CG_rough_{n_qubit}.pdf", bbox_inches="tight")
    plt.show()

# %%
import time

n = 9
seed = 0
kind = "pure"
print(f"{n=}")
np.random.seed(seed)
psi = make_random_quantum_state(kind, n, seed)
t0 = time.perf_counter()
stabilizer_extent, extends, max_values, _ = calculate_extent_CG(
    n, psi, Amat_method="rough"
)
t1 = time.perf_counter()
print(f"{stabilizer_extent=} {t1-t0=}")

with open(f"../data/CG_rough/{kind}_{n}_data.txt", mode="w") as f:
    for i in range(len(extends)):
        print(f"{extends[i]} {max_values[i]}", file=f)

with open(f"../data/CG_rough/{kind}_{n}_time.txt", mode="w") as f:
    print(t1 - t0, file=f)

visualize_result(n, extends, max_values)
# Out:
# n=9
# CG: n=9, method='mosek'
# start: calculate dots
# Case k=n done | current max: 0.216723
# Case k=n-1 | current max:0.208035
# Case k=n-1 | current max:0.213931
# Case k=n-1 | current max:0.209915
# Case k=n-1 | current max:0.206782
# Case k=n-1 | current max:0.195802
# Case k=n-1 | current max:0.211992
# Case k=n-1 | current max:0.203492
# Case k=n-1 | current max:0.211399
# Case k=n-1 | current max:0.207039
# Case k=n-1 | current max:0.221013
# A matrix construction done
# iteration: 1 / 30, Amat.shape = (512, 100000)
# start: solve SOCP
# stabilizer_extent=28.572297206456987
# start: calculate dual dots
# Case k=n done | current max: 1.18952
# Case k=n-1 | current max:1.18299
# Case k=n-1 | current max:1.20106
# Case k=n-1 | current max:1.14695
# Case k=n-1 | current max:1.19441
# Case k=n-1 | current max:1.23278
# Case k=n-1 | current max:1.14419
# Case k=n-1 | current max:1.11947
# Case k=n-1 | current max:1.18447
# Case k=n-1 | current max:1.18673
# Case k=n-1 | current max:1.13883
# A matrix construction done
# # of violations(LB): 1371
# iteration: 2 / 30, Amat.shape = (512, 2623)
# start: solve SOCP
# stabilizer_extent=27.94806132119385
# start: calculate dual dots
# Case k=n done | current max: 1.20513
# Case k=n-1 | current max:1.18948
# Case k=n-1 | current max:1.15675
# Case k=n-1 | current max:1.19885
# Case k=n-1 | current max:1.13842
# Case k=n-1 | current max:1.19349
# Case k=n-1 | current max:1.17786
# Case k=n-1 | current max:1.13048
# Case k=n-1 | current max:1.16171
# Case k=n-1 | current max:1.14541
# Case k=n-1 | current max:1.17282
# A matrix construction done
# # of violations(LB): 3321
# iteration: 3 / 30, Amat.shape = (512, 4509)
# start: solve SOCP
# stabilizer_extent=27.447811198738204
# start: calculate dual dots
# Case k=n done | current max: 1.22539
# Case k=n-1 | current max:1.13596
# Case k=n-1 | current max:1.14503
# Case k=n-1 | current max:1.13997
# Case k=n-1 | current max:1.16273
# Case k=n-1 | current max:1.12418
# Case k=n-1 | current max:1.20175
# Case k=n-1 | current max:1.22752
# Case k=n-1 | current max:1.17175
# Case k=n-1 | current max:1.24154
# Case k=n-1 | current max:1.24112
# A matrix construction done
# # of violations(LB): 2029
# iteration: 4 / 30, Amat.shape = (512, 3197)
# start: solve SOCP
# stabilizer_extent=27.024052198892903
# start: calculate dual dots
# Case k=n done | current max: 1.18749
# Case k=n-1 | current max:1.14671
# Case k=n-1 | current max:1.12421
# Case k=n-1 | current max:1.18449
# Case k=n-1 | current max:1.15541
# Case k=n-1 | current max:1.1561
# Case k=n-1 | current max:1.16093
# Case k=n-1 | current max:1.11475
# Case k=n-1 | current max:1.17779
# Case k=n-1 | current max:1.21293
# Case k=n-1 | current max:1.10872
# A matrix construction done
# # of violations(LB): 2468
# iteration: 5 / 30, Amat.shape = (512, 3588)
# start: solve SOCP
# stabilizer_extent=26.71223074724407
# start: calculate dual dots
# Case k=n done | current max: 1.13112
# Case k=n-1 | current max:1.09549
# Case k=n-1 | current max:1.12081
# Case k=n-1 | current max:1.09152
# Case k=n-1 | current max:1.14318
# Case k=n-1 | current max:1.10544
# Case k=n-1 | current max:1.16036
# Case k=n-1 | current max:1.13431
# Case k=n-1 | current max:1.13123
# Case k=n-1 | current max:1.12996
# Case k=n-1 | current max:1.13372
# A matrix construction done
# # of violations(LB): 885
# iteration: 6 / 30, Amat.shape = (512, 2000)
# start: solve SOCP
# stabilizer_extent=26.517309247458016
# start: calculate dual dots
# Case k=n done | current max: 1.13658
# Case k=n-1 | current max:1.07596
# Case k=n-1 | current max:1.15327
# Case k=n-1 | current max:1.11517
# Case k=n-1 | current max:1.16566
# Case k=n-1 | current max:1.23307
# Case k=n-1 | current max:1.08145
# Case k=n-1 | current max:1.07407
# Case k=n-1 | current max:1.1445
# Case k=n-1 | current max:1.13789
# Case k=n-1 | current max:1.16224
# A matrix construction done
# # of violations(LB): 1143
# iteration: 7 / 30, Amat.shape = (512, 2239)
# start: solve SOCP
# stabilizer_extent=26.325389491495677
# start: calculate dual dots
# Case k=n done | current max: 1.15582
# Case k=n-1 | current max:1.17351
# Case k=n-1 | current max:1.10358
# Case k=n-1 | current max:1.10398
# Case k=n-1 | current max:1.09553
# Case k=n-1 | current max:1.15568
# Case k=n-1 | current max:1.14413
# Case k=n-1 | current max:1.17667
# Case k=n-1 | current max:1.14015
# Case k=n-1 | current max:1.10639
# Case k=n-1 | current max:1.11786
# A matrix construction done
# # of violations(LB): 890
# iteration: 8 / 30, Amat.shape = (512, 1989)
# start: solve SOCP
# stabilizer_extent=26.147546570778093
# start: calculate dual dots
# Case k=n done | current max: 1.21551
# Case k=n-1 | current max:1.10237
# Case k=n-1 | current max:1.09948
# Case k=n-1 | current max:1.12218
# Case k=n-1 | current max:1.13203
# Case k=n-1 | current max:1.13743
# Case k=n-1 | current max:1.10563
# Case k=n-1 | current max:1.14676
# Case k=n-1 | current max:1.15337
# Case k=n-1 | current max:1.1347
# Case k=n-1 | current max:1.0644
# A matrix construction done
# # of violations(LB): 903
# iteration: 9 / 30, Amat.shape = (512, 1984)
# start: solve SOCP
# stabilizer_extent=25.98517106204719
# start: calculate dual dots
# Case k=n done | current max: 1.12652
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 10
#       8 psi = make_random_quantum_state(kind, n, seed)
#       9 t0 = time.perf_counter()
# ---> 10 stabilizer_extent, extends, max_values, _ = calculate_extent_CG(
#      11     n, psi, Amat_method="rough"
#      12 )
#      13 t1 = time.perf_counter()
#      14 print(f"{stabilizer_extent=} {t1-t0=}")
#
# File ~/stabilizer_extent/exputils/extent/cg.py:40, in calculate_extent_CG(n, psi, method, Amat_method, verbose)
#      38 print(f"{stabilizer_extent=}")
#      39 print("start: calculate dual dots")
# ---> 40 dual_dots_state = get_Amat(n, dual, True)
#      41 if dual_dots_state.shape[1] == 0:
#      42     print("OPTIMAL!")
#
# File ~/stabilizer_extent/exputils/extent/cg.py:22, in calculate_extent_CG.<locals>.<lambda>(*args)
#      13 print(f"CG: {n=}, {method=}")
#      14 print("start: calculate dots")
#      15 get_Amat = (
#      16     (
#      17         lambda *args: get_topK_Amat(
#      18             *args, K=10000 if n <= 8 else 100000, verbose=True
#      19         )
#      20     )
#      21     if Amat_method == "topK"
# ---> 22     else (lambda *args: get_rough_Amat(*args, verbose=True))
#      23 )
#      24 current_Amat = get_Amat(n, psi, False)
#      25 iter_max = 30
#
# File ~/stabilizer_extent/exputils/dot/get_rough_Amat.py:20, in get_rough_Amat(n, psi, is_dual_mode, verbose)
#      18 with subprocess.Popen([path], stderr=subprocess.PIPE) as p:
#      19     if verbose:
# ---> 20         for line in p.stderr:
#      21             print(line.decode("utf-8", errors="ignore"), end="")
#      22     p.wait()
#
# KeyboardInterrupt:
